# %% [markdown]
# <a href="https://colab.research.google.com/github/Juannovoa23/Alura-challenge/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalación de Java y Spark en Google Colab
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null

# Descargar Spark 3.4.1 desde un enlace correcto
# !wget -q https://archive.apache.org/dist/spark/spark-3.4.1/spark-3.4.1-bin-hadoop3.tgz

# Extraer Spark
# !tar -xzf spark-3.4.1-bin-hadoop3.tgz

# Instalar dependencias
# !pip install -q findspark openpyxl

# %%
import os
import findspark

os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.4.1-bin-hadoop3"
findspark.init()

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Excel Analysis") \
    .config("spark.executor.memory", "2g") \
    .getOrCreate()

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Excel Analysis") \
    .config("spark.executor.memory", "2g") \
    .getOrCreate()

# %%
import pandas as pd
from google.colab import files

uploaded = files.upload()
excel_path = list(uploaded.keys())[0]
df_excel = pd.read_excel(excel_path)
df_excel.to_csv("data.csv", index=False)
# Out:
#      <input type="file" id="files-6c093c6a-0586-4324-87f8-06e4fd7dbb4a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6c093c6a-0586-4324-87f8-06e4fd7dbb4a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = spark.read.option("header", True).option("inferSchema", True).csv("data.csv")
df.printSchema()
df.show(200)
# Out:
# root
#  |-- Tipo: Promedio, Base de tiempo: 1 Hora, 01-01-2024 01:00-31-12-2024 00:00: string (nullable = true)
#  |-- Unnamed: 1: string (nullable = true)
#  |-- Unnamed: 2: string (nullable = true)
#  |-- Unnamed: 3: string (nullable = true)
#  |-- Unnamed: 4: string (nullable = true)
#  |-- Unnamed: 5: string (nullable = true)
#  |-- Unnamed: 6: string (nullable = true)
#  |-- Unnamed: 7: string (nullable = true)
#  |-- Unnamed: 8: string (nullable = true)
#  |-- Unnamed: 9: string (nullable = true)
#  |-- Unnamed: 10: string (nullable = true)
#  |-- Unnamed: 11: string (nullable = true)
#  |-- Unnamed: 12: string (nullable = true)
#  |-- Unnamed: 13: string (nullable = true)
#  |-- Unnamed: 14: string (nullable = true)
#  |-- Unnamed: 15: string (nullable = true)
#  |-- Unnamed: 16: string (nullable = true)
#  |-- Unnamed: 17: string (nullable = true)
#
# ...
